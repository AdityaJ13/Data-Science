# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# In C:\Users\adity\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\adity\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\adity\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\adity\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
df = pd.read_excel('Sales_Data_Project.xlsx')

# %%
df.shape
# Out:
# (2747, 20)

# %%
df.head()
# Out:
#    ORDER NUMBER  QUANTITY ORDERED  PRICE EACH  ORDER LINE    SALES ORDER DATE  \
# 0         10107                30       95.70           2  2871.00 2018-02-24
# 1         10121                34       81.35           5  2765.90 2018-05-07
# 2         10134                41       94.74           2  3884.34 2018-07-01
# 3         10145                45       83.26           6  3746.70 2018-08-25
# 4         10168                36       96.66           1  3479.76 2018-10-28
#
#    DAYS_SINCE_LASTORDER   STATUS     CATEGORY  MSRP PRODUCT CODE  \
# 0                   828  Shipped  Motorcycles    95     S10_1678
# 1                   757  Shipped  Motorcycles    95     S10_1678
# 2                   703  Shipped  Motorcycles    95     S10_1678
# 3                   649  Shipped  Motorcycles    95     S10_1678
# 4                   586  Shipped  Motorcycles    95     S10_1678
#
#           CUSTOMER NAME             PHONE                        ADDRESS  \
# ...

# %%
df.tail()
# Out:
#       ORDER NUMBER  QUANTITY ORDERED  PRICE EACH  ORDER LINE    SALES  \
# 2742         10350                20      112.22          15  2244.40
# 2743         10373                29      137.19           1  3978.51
# 2744         10386                43      125.99           4  5417.57
# 2745         10397                34       62.24           1  2116.16
# 2746         10414                47       65.52           9  3079.44
#
#      ORDER DATE  DAYS_SINCE_LASTORDER    STATUS CATEGORY  MSRP PRODUCT CODE  \
# 2742 2019-12-02                  2924   Shipped    Ships    54     S72_3212
# 2743 2020-01-31                  2865   Shipped    Ships    54     S72_3212
# 2744 2020-03-01                  2836  Resolved    Ships    54     S72_3212
# 2745 2020-03-28                  2810   Shipped    Ships    54     S72_3212
# 2746 2020-05-06                  2772   On Hold    Ships    54     S72_3212
#
#                 CUSTOMER NAME           PHONE                ADDRESS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDER NUMBER          2747 non-null   int64
#  1   QUANTITY ORDERED      2747 non-null   int64
#  2   PRICE EACH            2747 non-null   float64
#  3   ORDER LINE            2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDER DATE            2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   CATEGORY              2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCT CODE          2747 non-null   object
#  11  CUSTOMER NAME         2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESS               2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
pd.DataFrame({'Columns':df.columns, 'Data Types':df.dtypes}).reset_index().drop('index',axis = 1)
# Out:
#                  Columns      Data Types
# 0           ORDER NUMBER           int64
# 1       QUANTITY ORDERED           int64
# 2             PRICE EACH         float64
# 3             ORDER LINE           int64
# 4                  SALES         float64
# 5             ORDER DATE  datetime64[ns]
# 6   DAYS_SINCE_LASTORDER           int64
# 7                 STATUS          object
# 8               CATEGORY          object
# 9                   MSRP           int64
# 10          PRODUCT CODE          object
# 11         CUSTOMER NAME          object
# 12                 PHONE          object
# 13               ADDRESS          object
# 14                  CITY          object
# 15           POSTAL CODE          object
# 16               COUNTRY          object
# 17      CONTACT LASTNAME          object
# 18     CONTACT FIRSTNAME          object
# 19             DEAL SIZE          object

# %%
def univariate(col):
    print('Description of',col,' is: -')
    print(df[col].describe())
    print(' ')
    print('-----------------------------------------------------------')
    print("Mean is: ", df[col].mean())
    print("Median is: ", df[col].median())
    print("Mode is: ", df[col].mode()[0])
    print('-----------------------------------------------------------')
    print(" ")
    
    print("Distribution of ", col, ' is: -')
    
    sns.displot(x = df[col], kde = True, height = 4)
    plt.axvline(x = df[col].mean(), color = 'green',label = 'mean')
    plt.axvline(x = df[col].median(), color = 'red', label = 'median')
    plt.axvline(x = df[col].mode()[0], color = 'yellow', label = 'mode')
    plt.legend()
    plt.show()
    
    print('-----------------------------------------------------------')
    print(' ')
    print('Boxplot of',col,' is: -')
    plt.figure(figsize = (3,2))
    sns.boxplot(x = df[col],width = .6)
    plt.show()
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    print(' ')

# %%
for i in df.select_dtypes(include = ['int64','float64']):
    univariate(i)
# Out:
# Description of ORDER NUMBER  is: -
# count     2747.000000
# mean     10259.761558
# std         91.877521
# min      10100.000000
# 25%      10181.000000
# 50%      10264.000000
# 75%      10334.500000
# max      10425.000000
# Name: ORDER NUMBER, dtype: float64
#
# -----------------------------------------------------------
# Mean is:  10259.761558063341
# Median is:  10264.0
# Mode is:  10106
# -----------------------------------------------------------
#
# Distribution of  ORDER NUMBER  is: -
# -----------------------------------------------------------
#
# Boxplot of ORDER NUMBER  is: -
# -----------------------------------------------------------
# -----------------------------------------------------------
#
# Description of QUANTITY ORDERED  is: -
# count    2747.000000
# mean       35.103021
# std         9.762135
# min         6.000000
# 25%        27.000000
# 50%        35.000000
# 75%        43.000000
# max        97.000000
# Name: QUANTITY ORDERED, dtype: float64
#
# ...

# %%
df.describe().T
# Out:
#                        count          mean          std       min        25%  \
# ORDER NUMBER          2747.0  10259.761558    91.877521  10100.00  10181.000
# QUANTITY ORDERED      2747.0     35.103021     9.762135      6.00     27.000
# PRICE EACH            2747.0    101.098951    42.042548     26.88     68.745
# ORDER LINE            2747.0      6.491081     4.230544      1.00      3.000
# SALES                 2747.0   3553.047583  1838.953901    482.13   2204.350
# DAYS_SINCE_LASTORDER  2747.0   1757.085912   819.280576     42.00   1077.000
# MSRP                  2747.0    100.691664    40.114802     33.00     68.000
#
#                            50%        75%       max
# ORDER NUMBER          10264.00  10334.500  10425.00
# QUANTITY ORDERED         35.00     43.000     97.00
# PRICE EACH               95.55    127.100    252.87
# ORDER LINE                6.00      9.000     18.00
# SALES                  3184.80   4503.095  14082.80
# ...

# %%
pd.DataFrame(df.isnull().sum(), columns = ['Null Values'])
# Out:
#                       Null Values
# ORDER NUMBER                    0
# QUANTITY ORDERED                0
# PRICE EACH                      0
# ORDER LINE                      0
# SALES                           0
# ORDER DATE                      0
# DAYS_SINCE_LASTORDER            0
# STATUS                          0
# CATEGORY                        0
# MSRP                            0
# PRODUCT CODE                    0
# CUSTOMER NAME                   0
# PHONE                           0
# ADDRESS                         0
# CITY                            0
# POSTAL CODE                     0
# COUNTRY                         0
# CONTACT LASTNAME                0
# CONTACT FIRSTNAME               0
# DEAL SIZE                       0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.select_dtypes(include = ['object']):
    print(i)
# Out:
# STATUS
# CATEGORY
# PRODUCT CODE
# CUSTOMER NAME
# PHONE
# ADDRESS
# CITY
# POSTAL CODE
# COUNTRY
# CONTACT LASTNAME
# CONTACT FIRSTNAME
# DEAL SIZE

# %%
df.STATUS.value_counts()
# Out:
# Shipped       2541
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
df.CATEGORY.value_counts()
# Out:
# Classic Cars        949
# Vintage Cars        579
# Motorcycles         313
# Planes              304
# Trucks and Buses    295
# Ships               230
# Trains               77
# Name: CATEGORY, dtype: int64

# %%
df.COUNTRY.value_counts()
# Out:
# USA            928
# Spain          342
# France         314
# Australia      185
# UK             144
# Italy          113
# Finland         92
# Norway          85
# Singapore       79
# Canada          70
# Denmark         63
# Germany         62
# Sweden          57
# Austria         55
# Japan           52
# Belgium         33
# Switzerland     31
# Philippines     26
# Ireland         16
# Name: COUNTRY, dtype: int64

# %%
df.CITY.value_counts()
# Out:
# Madrid            304
# San Rafael        180
# NYC               152
# Singapore          79
# Paris              70
#                  ...
# South Brisbane     15
# Brisbane           15
# Munich             14
# Burbank            13
# Charleroi           8
# Name: CITY, Length: 71, dtype: int64

# %%
df['DEAL SIZE'].value_counts()
# Out:
# Medium    1349
# Small     1246
# Large      152
# Name: DEAL SIZE, dtype: int64

# %% [markdown]
# #### Checking Outliers

# %%
def box(col):
    print('Boxplot of',col,' is: -')
    plt.figure(figsize = (4,3))
    sns.boxplot(x = df[col],width = .6)
    plt.show()

# %%
for i in df.select_dtypes(include = ['int64','float64']):
    box(i)
# Out:
# Boxplot of ORDER NUMBER  is: -
# Boxplot of QUANTITY ORDERED  is: -
# Boxplot of PRICE EACH  is: -
# Boxplot of ORDER LINE  is: -
# Boxplot of SALES  is: -
# Boxplot of DAYS_SINCE_LASTORDER  is: -
# Boxplot of MSRP  is: -

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (10,7))
sns.heatmap(df.corr(), annot = True, cmap = 'plasma')
# Out:
# <AxesSubplot:>

# %%
df1 = pd.read_excel('RFM_Project_4segments.xlsx')

# %%
df1.head()
# Out:
#              CUSTOMER NAME  ORDER NUMBER  QUANTITY ORDERED  PRICE EACH  \
# 0           AV Stores, Co.            51         34.862745   91.084510
# 1             Alpha Cognac            20         34.350000  101.160000
# 2       Amica Models & Co.            26         32.423077  110.852692
# 3  Anna's Decorations, Ltd            46         31.934783  106.424130
# 4        Atelier graphique             7         38.571429   92.238571
#
#    ORDER LINE      SALES ORDER DATE  DAYS_SINCE_LASTORDER   STATUS  \
# 0          51  157807.81 2019-10-14                   421  Shipped
# 1          20   70488.44 2018-11-08                   675  Shipped
# 2          26   94117.26 2019-08-17                   328  Shipped
# 3          46  153996.13 2020-03-09                   131  Shipped
# 4           7   24179.96 2019-09-27                   312  Shipped
#
#        CATEGORY  ...    COUNTRY  CONTACT LASTNAME CONTACT FIRSTNAME DEAL SIZE  \
# ...

# %% [markdown]
# ## Best Customers

# %%
data1 = df1[(df1.Recency_HML=='High Valued') & (df1.Frequency_HML=='High Valued') &(df1.Monetary_HML == 'High Valued')]

# %%
data1[['CUSTOMER NAME','Recency_HML','Frequency_HML','Monetary_HML']]
# Out:
#                    CUSTOMER NAME  Recency_HML Frequency_HML Monetary_HML
# 26      Danish Wholesale Imports  High Valued   High Valued  High Valued
# 32         Euro Shopping Channel  High Valued   High Valued  High Valued
# 41           L'ordine Souveniers  High Valued   High Valued  High Valued
# 43             La Rochelle Gifts  High Valued   High Valued  High Valued
# 53  Mini Gifts Distributors Ltd.  High Valued   High Valued  High Valued
# 63            Reims Collectables  High Valued   High Valued  High Valued
# 67         Salzburg Collectables  High Valued   High Valued  High Valued
# 72     Souveniers And Things Co.  High Valued   High Valued  High Valued
# 78     The Sharp Gifts Warehouse  High Valued   High Valued  High Valued

# %% [markdown]
# ## Risk Customers

# %%
data2 = df1[(df1.Recency_HML == 'Risk/Potential')&(df1.Frequency_HML == 'Risk/Potential')&(df1.Monetary_HML == 'Risk/Potential')]

# %%
data2[['CUSTOMER NAME','Recency_HML','Frequency_HML','Monetary_HML']]
# Out:
#                      CUSTOMER NAME     Recency_HML   Frequency_HML  \
# 13            Blauer See Auto, Co.  Risk/Potential  Risk/Potential
# 17  Canadian Gift Exchange Network  Risk/Potential  Risk/Potential
# 31              Enaco Distributors  Risk/Potential  Risk/Potential
# 51                   Mini Classics  Risk/Potential  Risk/Potential
# 54    Motor Mint Distributors Inc.  Risk/Potential  Risk/Potential
# 88               giftsbymail.co.uk  Risk/Potential  Risk/Potential
#
#       Monetary_HML
# 13  Risk/Potential
# 17  Risk/Potential
# 31  Risk/Potential
# 51  Risk/Potential
# 54  Risk/Potential
# 88  Risk/Potential

# %% [markdown]
# ## Loyal Customers

# %%
data3 = df1[(df1.Recency_HML == 'High Valued')]

# %%
data3[['CUSTOMER NAME','Recency_HML','Frequency_HML','Monetary_HML']]
# Out:
#                    CUSTOMER NAME  Recency_HML   Frequency_HML    Monetary_HML
# 1                   Alpha Cognac  High Valued           Churn           Churn
# 5   Australian Collectables, Ltd  High Valued  Risk/Potential           Churn
# 9               Auto Canal Petit  High Valued      Mid Valued      Mid Valued
# 26      Danish Wholesale Imports  High Valued     High Valued     High Valued
# 27         Diecast Classics Inc.  High Valued      Mid Valued     High Valued
# 32         Euro Shopping Channel  High Valued     High Valued     High Valued
# 34               Gift Depot Inc.  High Valued  Risk/Potential      Mid Valued
# 36             Gifts4AllAges.com  High Valued  Risk/Potential  Risk/Potential
# 37              Handji Gifts& Co  High Valued     High Valued      Mid Valued
# 41           L'ordine Souveniers  High Valued     High Valued     High Valued
# 43             La Rochelle Gifts  High Valued     High Valued     High Valued
# ...

# %% [markdown]
# ## Lost Customers

# %%
data4 = data2 = df1[(df1.Recency_HML == 'Churn')&(df1.Frequency_HML == 'Churn')&(df1.Monetary_HML =='Churn')]

# %%
data4[['CUSTOMER NAME','Recency_HML','Frequency_HML','Monetary_HML']]
# Out:
#                          CUSTOMER NAME Recency_HML Frequency_HML Monetary_HML
# 8                   Auto Assoc. & Cie.       Churn         Churn        Churn
# 12  Bavarian Collectables Imports, Co.       Churn         Churn        Churn
# 15                         CAF Imports       Churn         Churn        Churn
# 16          Cambridge Collectables Co.       Churn         Churn        Churn
# 20             Clover Collections, Co.       Churn         Churn        Churn
# 25            Daedalus Designs Imports       Churn         Churn        Churn
# 29      Double Decker Gift Stores, Ltd       Churn         Churn        Churn
# 40          Iberia Gift Imports, Corp.       Churn         Churn        Churn
# 58            Online Mini Collectables       Churn         Churn        Churn
# 59                Osaka Souveniers Co.       Churn         Churn        Churn
# 70            Signal Collectibles Ltd.       Churn         Churn        Churn
# ...
